# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5]
y=[10,23,14,15,17]

# %%
plt.plot(x,y,"g")

# %%
plt.plot(x,y,"g*--",markersize=20,alpha=0.5)

# %%
plt.bar([1,2,3,4,5],[2,4,3,1,5],width=0.5)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.boxplot([1,2,3,4,5])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26d95b040d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26d95b04df0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26d95b00790>],
#  'medians': [<matplotlib.lines.Line2D at 0x26d95aea820>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26d95b34cd0>],
#  'means': []}
