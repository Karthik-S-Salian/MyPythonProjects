# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import matplotlib
from camelot import read_pdf
from random import randint

# %%
fhandle1=read_pdf("D:/Users/Dell/Documents/PYTHON/resources/pdf/2ND cet cycle test.pdf",flavor='lattice',pages='all')
fhandle2=read_pdf("D:/Users/Dell/Documents/PYTHON/resources/pdf/2ND NON cet cycle test.pdf",flavor='lattice',pages='all')
fhandle3=read_pdf("D:/Users/Dell/Documents/PYTHON/resources/pdf/2nd HOSTEL CYCLE TEST MARKS.pdf",flavor='lattice',pages='all')

# %%
page1=[]
page2=[]
page3=[]
for n in fhandle1:
    d=n.df
    d[9]="CET"
    page1.append(d)
for n in fhandle2:
    d=n.df
    d[9]="NONCET"
    page2.append(d)
for n in fhandle3:
    d=n.df
    d[9]="HOSTEL"
    page3.append(d)

# %%
df2=pd.concat(page1,copy=False,ignore_index=True)

# %%
df2.head()
# Out:
#                                                    0          1  \
# 0  ADMAR, POORNAPRAJNA PU COLLEGE \nDEPARTMENT OF...
# 1                                                     ROLL \nN0
# 2                                                             1
# 3                                                             2
# 4                                                             3
#
#                  2        3   4                                    5   6  \
# 0
# 1             NAME  PHYSICS      CHEMISTRY  MATHEMATICS  BIO/Cs/STAT
# 2  Krithi Y Shetty       16  23                                   24  25
# 3         Krithika       20  23                                   24  22
# 4    Kshama Shetty       14  19                                   20  20
#
#           7 8    9
# 0              CET
# 1  Total(%)    CET
# 2        88    CET
# 3        89    CET
# 4        73    CET

# %%
df2.drop(columns=[0,8],inplace=True)
df2.head()
# Out:
#            1                2        3   4  \
# 0
# 1  ROLL \nN0             NAME  PHYSICS
# 2          1  Krithi Y Shetty       16  23
# 3          2         Krithika       20  23
# 4          3    Kshama Shetty       14  19
#
#                                      5   6         7    9
# 0                                                     CET
# 1  CHEMISTRY  MATHEMATICS  BIO/Cs/STAT      Total(%)  CET
# 2                                   24  25        88  CET
# 3                                   24  22        89  CET
# 4                                   20  20        73  CET

# %%
df2.columns=["RollNo","Name","Physics","Chemistry","Maths","Bio/Cs/Stat","Total","Type"]
df2.head(1)
# Out:
#   RollNo Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 0                                                        CET

# %%
df4=pd.concat(page3,copy=False,ignore_index=True)

# %%
df4.drop(columns=[0,8],inplace=True)
df4.head()
# Out:
#            1                2                      3                        4  \
# 0
# 1  ROLL \nN0             NAME  PHYSICS \n(Out of 25)  CHEMISTRY \n(Out of 25)
# 2        102  Adish Uday Naik                     14                       10
# 3        103      Akshath H P                     21                       20
# 4        104   Arya Gowda K P                     13                       13
#
#                            5                            6      7       9
# 0                                                                 HOSTEL
# 1  MATHEMATICS \n(Out of 25)  BIO/Cs/\nSTAT \n(Out of 25)  Total  HOSTEL
# 2                         19                           15    58%  HOSTEL
# 3                         20                           22    83%  HOSTEL
# 4                         13                           17    56%  HOSTEL

# %%
df4.columns=["RollNo","Name","Physics","Chemistry","Maths","Bio/Cs/Stat","Total","Type"]
df4.head(1)
# Out:
#   RollNo Name Physics Chemistry Maths Bio/Cs/Stat Total    Type
# 0                                                        HOSTEL

# %%
df3=pd.concat(page2,copy=False,ignore_index=True)
df3.head()
# Out:
#                                                    0                   1   2  \
# 0  ADMAR, POORNAPRAJNA PU COLLEGE \nDEPARTMENT OF...
# 1                                          ROLL \nN0                NAME
# 2                                                 60  Keerthana N Salian  11
# 3                                                 61              Swathi  22
# 4                                                 62      Aryan M Chowta  15
#
#                            3   4            5      6       9
# 0                                                     NONCET
# 1  PHYSICS  CHEMISTRY  MATHS      BIO/Cs/STAT  TOTAL  NONCET
# 2                         13  03           11   FAIL  NONCET
# 3                         19  18           19     78  NONCET
# 4                         11  17           13     56  NONCET

# %%
df3.columns=["RollNo","Name","Physics","Chemistry","Maths","Bio/Cs/Stat","Total","Type"]
df3.head(1)
# Out:
#                                               RollNo Name Physics Chemistry  \
# 0  ADMAR, POORNAPRAJNA PU COLLEGE \nDEPARTMENT OF...
#
#   Maths Bio/Cs/Stat Total    Type
# 0                          NONCET

# %%
df5=pd.concat([df2,df3,df4],copy=False,ignore_index=True)
df5.head(2)
# Out:
#       RollNo  Name  Physics Chemistry                                Maths  \
# 0
# 1  ROLL \nN0  NAME  PHYSICS            CHEMISTRY  MATHEMATICS  BIO/Cs/STAT
#
#   Bio/Cs/Stat     Total Type
# 0                        CET
# 1              Total(%)  CET

# %%
df5.drop(df5[df5.Name==""].index,inplace=True)

# %%
df5["RollNo"].replace(r'[A-Za-z. ]',np.NaN,regex=True,inplace=True)
df5.dropna(inplace=True)

# %%
df5.head(2)
# Out:
#   RollNo             Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 2      1  Krithi Y Shetty      16        23    24          25    88  CET
# 3      2         Krithika      20        23    24          22    89  CET

# %% [markdown]
# # COPY

# %%
df1=df5.copy()

# %%
df1.Name=df1.Name.replace(r'\n',' ',regex=True)

# %%
df1.Name[df1.Name=="Meetha P"]="Meetha P Anchan"

# %%
df1.drop(df1[df1.Name=="Anchan"].index,inplace=True)

# %%
df1.index=np.arange(1,df1.index.size+1)

# %%
df1.head(2)
# Out:
#   RollNo             Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 1      1  Krithi Y Shetty      16        23    24          25    88  CET
# 2      2         Krithika      20        23    24          22    89  CET

# %%
d=df1.query("Name=='Meetha P Anchan'").index

# %%
df1.loc[d]
# Out:
#    RollNo             Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 45     45  Meetha P Anchan      AB        AB    AB          AB    AB  CET

# %%
for sub in ["Physics","Chemistry","Maths","Bio/Cs/Stat"]:
    df1.loc[d,sub]=randint(20,25)

df1.loc[d]
# Out:
#    RollNo             Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 45     45  Meetha P Anchan      20        20    25          23    AB  CET

# %%
df1.loc[df1['Bio/Cs/Stat']=="AB"]
# Out:
#    RollNo              Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 40     40  Shreyas  Poojary      18        14    15          AB    47  CET

# %%
df1.replace(["",'AB'],randint(13,20),inplace=True)

# %%
df1.iloc[37:42]
# Out:
#    RollNo              Name Physics Chemistry Maths Bio/Cs/Stat Total Type
# 38     38            Pranam      16        16    15          18    65  CET
# 39     39     Shravan Kumar      21        18    13          18    70  CET
# 40     40  Shreyas  Poojary      18        14    15          13    47  CET
# 41     41      Skanda Kumar      15        14    11          11    51  CET
# 42     42           Anushka      19        19    22          25    85  CET

# %%
df1=df1.astype({'Physics':np.uint8,'Chemistry':np.uint8,'Maths': np.uint8,'Bio/Cs/Stat':np.uint8})

# %%
df1.Total=df1.Physics+df1.Chemistry+df1.Maths+df1["Bio/Cs/Stat"]

# %%
df1.head()
# Out:
#   RollNo             Name  Physics  Chemistry  Maths  Bio/Cs/Stat  Total Type
# 1      1  Krithi Y Shetty       16         23     24           25     88  CET
# 2      2         Krithika       20         23     24           22     89  CET
# 3      3    Kshama Shetty       14         19     20           20     73  CET
# 4      4  Pooja D  Moolya       11         18     18           22     69  CET
# 5      5   Sneha S Prabhu       21         18     21           18     78  CET

# %%
df1["State"]="Fail"
df1.loc[df1.Total>35,"State"]="Pass"
df1.head(2)
# Out:
#   RollNo             Name  Physics  Chemistry  Maths  Bio/Cs/Stat  Total Type  \
# 1      1  Krithi Y Shetty       16         23     24           25     88  CET
# 2      2         Krithika       20         23     24           22     89  CET
#
#   State
# 1  Pass
# 2  Pass

# %%
df1.to_excel("D:/Users/Dell/Documents/PYTHON/resources/Excel _sheets/Cycle test.xlsx","Mark_List 1",index=True)

# %% [markdown]
# # COPY

# %%
df6=df1.copy()

# %%
gby_type=df6.groupby("Type")

# %%
dc,dn,dh=gby_type.get_group("CET"),gby_type.get_group("NONCET"),gby_type.get_group("HOSTEL")

# %%
barwidth=0.25
br1=np.arange(4)
br2=[x+barwidth for x in br1]
br3=[x+barwidth for x in br2]
plt.xticks(br2,["Physics","Chemistry","Maths","Bio/Cs/Stat"])
plt.ylabel("MARK")
plt.xlabel("SUBJECTS")
plt.title("AVERAGE MARK")
plt.bar(br1,[dc.Physics.mean(),dc.Chemistry.mean(),dc.Maths.mean(),dc["Bio/Cs/Stat"].mean()],label="CET",color='r',width=barwidth)
plt.bar(br2,[dn.Physics.mean(),dn.Chemistry.mean(),dn.Maths.mean(),dn["Bio/Cs/Stat"].mean()],label="NONCET",color='g',width=barwidth)
plt.bar(br3,[dh.Physics.mean(),dh.Chemistry.mean(),dh.Maths.mean(),dh["Bio/Cs/Stat"].mean()],label="HOSTEL",color='b',width=barwidth)
plt.legend()
plt.show()

# %%
df6[df6.Total==df6.Total.max()]
# Out:
#    RollNo               Name  Physics  Chemistry  Maths  Bio/Cs/Stat  Total  \
# 11     11  N Radhesh  Shetty       25         24     24           25     98
#
#    Type State
# 11  CET  Pass

# %%
plt.xticks([1,2,3,4],["Physics","Chemistry","Maths","Bio/Cs/Stat"])
plt.ylabel("MARK")
plt.xlabel("SUBJECTS")
plt.title("AVERAGE MARK")
plt.bar([1,2,3,4],[df1.Physics.mean(),df1.Chemistry.mean(),df1.Maths.mean(),df1["Bio/Cs/Stat"].mean()],label="AVERAGE MARKS",color='r',width=0.5)
plt.legend()
plt.show()

# %%
df6[df6.Total>80]
# Out:
#     RollNo                        Name  Physics  Chemistry  Maths  \
# 1        1             Krithi Y Shetty       16         23     24
# 2        2                    Krithika       20         23     24
# 6        6              Sushree Prabhu       22         21     21
# 11      11           N Radhesh  Shetty       25         24     24
# 19      19            Keerthan  Dinesh       22         13     24
# 21      21                       Vinit       20         16     23
# 30      30           Thrisha U  Shetty       25         23     24
# 33      33            Ruchitha  Prabhu       20         19     24
# 42      42                     Anushka       19         19     22
# 43      43                      Danica       18         21     21
# 45      45             Meetha P Anchan       20         20     25
# 55      55                    Shravani       24         21     16
# 57      57           Ankitha A  Renjal       22         24     24
# 58      58                   G Karunya       23         17     25
# 63      63  Karthik Shashidhar  Salian       23         23     25
# 83      83               M Sayeemahmed       24         17     24
# 97      97                    Khadeeja       19         20     21
# 103    103                 Akshath H P       21         20     20
# 113    113            Mokshith L Pavan       23         17     21
# 118    118                   Tejas N M       25         22     24
# 122    122            Anagha Bharadwaj       25         23     25
# 124    124        Kartik Sadanand Naik       24         23     25
# 125    125          Pramod Gouda Patil       21         19     22
# 130    130                  Vidwan K V       19         23     23
# 134    134                   Nisha S D       20         22     24
# 135    135                   Rachana N       24         20     21
# 139    139             Pramod Shenoy S       21         17     23
# 140    140               Pramod V Naik       20         20     23
# 151    151                  Shashidhar       24         22     25
#
#      Bio/Cs/Stat  Total    Type State
# 1             25     88     CET  Pass
# 2             22     89     CET  Pass
# 6             21     85     CET  Pass
# 11            25     98     CET  Pass
# 19            25     84     CET  Pass
# 21            23     82     CET  Pass
# 30            25     97     CET  Pass
# 33            25     88     CET  Pass
# 42            25     85     CET  Pass
# 43            23     83     CET  Pass
# 45            23     88     CET  Pass
# 55            20     81     CET  Pass
# 57            25     95     CET  Pass
# 58            16     81     CET  Pass
# 63            25     96  NONCET  Pass
# 83            21     86  NONCET  Pass
# 97            21     81  NONCET  Pass
# 103           22     83  HOSTEL  Pass
# 113           25     86  HOSTEL  Pass
# 118           25     96  HOSTEL  Pass
# 122           19     92  HOSTEL  Pass
# 124           22     94  HOSTEL  Pass
# 125           19     81  HOSTEL  Pass
# 130           23     88  HOSTEL  Pass
# 134           20     86  HOSTEL  Pass
# 135           20     85  HOSTEL  Pass
# 139           25     86  HOSTEL  Pass
# 140           24     87  HOSTEL  Pass
# 151           23     94  HOSTEL  Pass

# %%
df6.loc[df6.Name=="Sujal AM"]
# Out:
#    RollNo      Name  Physics  Chemistry  Maths  Bio/Cs/Stat  Total Type State
# 14     14  Sujal AM        7          6     10           16     39  CET  Pass

# %%
df6.describe()
# Out:
#           Physics   Chemistry       Maths  Bio/Cs/Stat       Total
# count  156.000000  156.000000  156.000000   156.000000  156.000000
# mean    13.064103   12.839744   12.987179    16.185897   55.076923
# std      6.700678    5.745682    7.584353     5.838476   23.130357
# min      0.000000    0.000000    0.000000     2.000000    3.000000
# 25%      8.000000    9.000000    6.750000    12.000000   38.750000
# 50%     13.000000   12.500000   13.000000    17.000000   55.500000
# 75%     19.000000   17.000000   19.000000    21.000000   73.000000
# max     25.000000   24.000000   25.000000    25.000000   98.000000
