# %%
import cv2
from matplotlib.pyplot import imshow
# %matplotlib inline
from IPython.display import Image

# %%
i=cv2.imread("resources\Images\minecraft.jpg",cv2.IMREAD_UNCHANGED)

# %%
Image(filename="resources\Images\minecraft.jpg")

# %%
imshow(i)
