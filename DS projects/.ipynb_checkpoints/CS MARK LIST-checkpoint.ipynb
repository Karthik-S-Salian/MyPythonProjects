# %%
import pandas as pd
import camelot as cm
import re

# %%
in_pdf=cm.read_pdf("D:/Users/Dell/Documents/PDF/unclassified/cs-marklist.pdf",flavor='lattice',pages='1,2,3')

# %%
page=[]
for n in in_pdf:
    y=n.df
    y.drop([0],inplace=True)
    page.append(y)
    
df2=pd.concat(page,ignore_index=True)

# %%
df3=df2.copy()

# %%
df3.columns=["Score","Name","Stream"]

# %%
df3.shape
# Out:
# (115, 3)

# %%
df3.head(30)
# Out:
#             Score                                        Name    Stream
# 0                                         17 / 25 Rifa ayesha   SCIENCE
# 1                                             21 / 25 Preethi   SCIENCE
# 2                                       11 / 25 Smaran shetty  COMMERCE
# 3                                     20 / 25 Ashish v shetty   SCIENCE
# 4   24 / 25 Vinit                                               SCIENCE
# 5                                     18 / 25 Nisha u acharya  COMMERCE
# 6                   24 / 25 Rahul Raghunath ShettigarCOMMERCE
# 7                                    20 / 25 N RADHESH SHETTY   SCIENCE
# 8                                       19 / 25 Mohammed adil  COMMERCE
# 9                                              25 / 25 Sumith   SCIENCE
# 10                                            18 / 25 Darshan  COMMERCE
# 11                               24 / 25 Sayed Mohammed Afzal  COMMERCE
# 12                                          24 / 25 Charan. K   SCIENCE
# 13                                           25 / 25 Thrupthi  COMMERCE
# 14                                             20 / 25 Damini  COMMERCE
# 15                                          22 / 25 Vaishnavi   SCIENCE
# 16                                    20 / 25 Poorna prajna.N  COMMERCE
# 17                              23 / 25 B.g venugopal karanth  COMMERCE
# 18                                     22 / 25 Thanvi S Sanil   SCIENCE
# 19                                    23 / 25 Sharan.p.shetty  COMMERCE
# 20                   24 / 25 Karthik Shashidhar SalianSCIENCE
# 21                                    20 / 25 Abhishek.s.shet   SCIENCE
# 22                                          17 / 25 Neha Amin  COMMERCE
# 23                 22 / 25 Meghna gopalkrishna salianCOMMERCE
# 24                                    21 / 25 Veeraj n kotian  COMMERCE
# 25                                     21 / 25 Rohith poojary  COMMERCE
# 26                                      21 / 25 Pramod V Naik   SCIENCE
# 27                                   21 / 25 Anshul A. Salian   SCIENCE
# 28                                     21 / 25 Mohammed Irfan   SCIENCE
# 29                                     21 / 25 Mohammed ciyaf   SCIENCE

# %%
df1=df3.copy()

# %%
df1["Stream"][df1.Stream==""]=df1.Name
df1.loc[df1["Score"]=='',"Score"]=df1.Name
df1["Name"][df1.Name==""]=df1.Score

# %%
df1.head(10)
# Out:
#                                          Score  \
# 0                          17 / 25 Rifa ayesha
# 1                              21 / 25 Preethi
# 2                        11 / 25 Smaran shetty
# 3                      20 / 25 Ashish v shetty
# 4                                24 / 25 Vinit
# 5                      18 / 25 Nisha u acharya
# 6    24 / 25 Rahul Raghunath ShettigarCOMMERCE
# 7                     20 / 25 N RADHESH SHETTY
# 8                        19 / 25 Mohammed adil
# 9                               25 / 25 Sumith
# 10                             18 / 25 Darshan
# 11                24 / 25 Sayed Mohammed Afzal
# 12                           24 / 25 Charan. K
# 13                            25 / 25 Thrupthi
# 14                              20 / 25 Damini
# 15                           22 / 25 Vaishnavi
# 16                     20 / 25 Poorna prajna.N
# 17               23 / 25 B.g venugopal karanth
# 18                      22 / 25 Thanvi S Sanil
# 19                     23 / 25 Sharan.p.shetty
# 20    24 / 25 Karthik Shashidhar SalianSCIENCE
# 21                     20 / 25 Abhishek.s.shet
# 22                           17 / 25 Neha Amin
# 23  22 / 25 Meghna gopalkrishna salianCOMMERCE
# 24                     21 / 25 Veeraj n kotian
# 25                      21 / 25 Rohith poojary
# 26                       21 / 25 Pramod V Naik
# 27                    21 / 25 Anshul A. Salian
# 28                      21 / 25 Mohammed Irfan
# 29                      21 / 25 Mohammed ciyaf
# 30                    23 / 25 Vignesh s shetty
# 31                     23 / 25 R Nayana kotian
# 32                      14 / 25 Shivaprakash u
# 33                      22 / 25 Abhay.G.Bhadri
# 34                       18 / 25 Reshel Dsilva
# 35                               24 / 25 AYUSH
# 36                    18 / 25 P Sudharshan rao
# 37                   21 / 25 Varsha  y Karkera
# 38                          24 / 25 Varshith G
# 39                             20 / 25 Karunya
# 40                   24 / 25 Tanushri V Shetty
# 41                          23 / 25 Poorvi Rao
# 42                 24 / 25 Deekshith.P.Poojary
# 43                18 / 25 Prajwal. R. Devadiga
# 44                           23 / 25 Manish PM
# 45                          19 / 25 Syed yusuf
# 46      22 / 25 shashidhar vishwakarma SCIENCE
# 47                          23 / 25 samrudhi s
# 48                              20 / 25 Arathi
# 49        18 / 25 ROSHAN DENZIEL AMANNASCIENCE
# 50                      24 / 25 Sanjana Gunaga
# 51                          16 / 25 Rahul bhat
# 52                      24 / 25 ARYAN M CHOWTA
# 53                     22 / 25 Ashith H kotian
# 54                       16 / 25 Shraddha yeri
# 55                      21 / 25 Mahammed Sinan
# 56                   23 / 25 Manish. Y poojary
# 57                      22 / 25 Krishna moolya
# 58                        20 / 25 Vinayak bhat
# 59                             18 / 25 shreyas
#
#                                           Name  \
# 0                          17 / 25 Rifa ayesha
# 1                              21 / 25 Preethi
# 2                        11 / 25 Smaran shetty
# 3                      20 / 25 Ashish v shetty
# 4                                24 / 25 Vinit
# 5                      18 / 25 Nisha u acharya
# 6    24 / 25 Rahul Raghunath ShettigarCOMMERCE
# 7                     20 / 25 N RADHESH SHETTY
# 8                        19 / 25 Mohammed adil
# 9                               25 / 25 Sumith
# 10                             18 / 25 Darshan
# 11                24 / 25 Sayed Mohammed Afzal
# 12                           24 / 25 Charan. K
# 13                            25 / 25 Thrupthi
# 14                              20 / 25 Damini
# 15                           22 / 25 Vaishnavi
# 16                     20 / 25 Poorna prajna.N
# 17               23 / 25 B.g venugopal karanth
# 18                      22 / 25 Thanvi S Sanil
# 19                     23 / 25 Sharan.p.shetty
# 20    24 / 25 Karthik Shashidhar SalianSCIENCE
# 21                     20 / 25 Abhishek.s.shet
# 22                           17 / 25 Neha Amin
# 23  22 / 25 Meghna gopalkrishna salianCOMMERCE
# 24                     21 / 25 Veeraj n kotian
# 25                      21 / 25 Rohith poojary
# 26                       21 / 25 Pramod V Naik
# 27                    21 / 25 Anshul A. Salian
# 28                      21 / 25 Mohammed Irfan
# 29                      21 / 25 Mohammed ciyaf
# 30                    23 / 25 Vignesh s shetty
# 31                     23 / 25 R Nayana kotian
# 32                      14 / 25 Shivaprakash u
# 33                      22 / 25 Abhay.G.Bhadri
# 34                       18 / 25 Reshel Dsilva
# 35                               24 / 25 AYUSH
# 36                    18 / 25 P Sudharshan rao
# 37                   21 / 25 Varsha  y Karkera
# 38                          24 / 25 Varshith G
# 39                             20 / 25 Karunya
# 40                   24 / 25 Tanushri V Shetty
# 41                          23 / 25 Poorvi Rao
# 42                 24 / 25 Deekshith.P.Poojary
# 43                18 / 25 Prajwal. R. Devadiga
# 44                           23 / 25 Manish PM
# 45                          19 / 25 Syed yusuf
# 46      22 / 25 shashidhar vishwakarma SCIENCE
# 47                          23 / 25 samrudhi s
# 48                              20 / 25 Arathi
# 49        18 / 25 ROSHAN DENZIEL AMANNASCIENCE
# 50                      24 / 25 Sanjana Gunaga
# 51                          16 / 25 Rahul bhat
# 52                      24 / 25 ARYAN M CHOWTA
# 53                     22 / 25 Ashith H kotian
# 54                       16 / 25 Shraddha yeri
# 55                      21 / 25 Mahammed Sinan
# 56                   23 / 25 Manish. Y poojary
# 57                      22 / 25 Krishna moolya
# 58                        20 / 25 Vinayak bhat
# 59                             18 / 25 shreyas
#
#                                         Stream
# 0                                      SCIENCE
# 1                                      SCIENCE
# 2                                     COMMERCE
# 3                                      SCIENCE
# 4                                      SCIENCE
# 5                                     COMMERCE
# 6    24 / 25 Rahul Raghunath ShettigarCOMMERCE
# 7                                      SCIENCE
# 8                                     COMMERCE
# 9                                      SCIENCE
# 10                                    COMMERCE
# 11                                    COMMERCE
# 12                                     SCIENCE
# 13                                    COMMERCE
# 14                                    COMMERCE
# 15                                     SCIENCE
# 16                                    COMMERCE
# 17                                    COMMERCE
# 18                                     SCIENCE
# 19                                    COMMERCE
# 20    24 / 25 Karthik Shashidhar SalianSCIENCE
# 21                                     SCIENCE
# 22                                    COMMERCE
# 23  22 / 25 Meghna gopalkrishna salianCOMMERCE
# 24                                    COMMERCE
# 25                                    COMMERCE
# 26                                     SCIENCE
# 27                                     SCIENCE
# 28                                     SCIENCE
# 29                                     SCIENCE
# 30                                    COMMERCE
# 31                                    COMMERCE
# 32                                    COMMERCE
# 33                                    COMMERCE
# 34                                    COMMERCE
# 35                                    COMMERCE
# 36                                    COMMERCE
# 37                                    COMMERCE
# 38                                     SCIENCE
# 39                                    COMMERCE
# 40                                    COMMERCE
# 41                                    COMMERCE
# 42                                     SCIENCE
# 43                                     SCIENCE
# 44                                     SCIENCE
# 45                                     SCIENCE
# 46      22 / 25 shashidhar vishwakarma SCIENCE
# 47                                    COMMERCE
# 48                                    COMMERCE
# 49        18 / 25 ROSHAN DENZIEL AMANNASCIENCE
# 50                                     SCIENCE
# 51                                     SCIENCE
# 52                                     SCIENCE
# 53                                    COMMERCE
# 54                                     SCIENCE
# 55                                     SCIENCE
# 56                                    COMMERCE
# 57                                    COMMERCE
# 58                                    COMMERCE
# 59                                     SCIENCE

# %%
df1.replace({
    "Name":['[0-9/]','SCIENCE','COMMERCE'],
    "Score":['/ 25','[A-Za-z..]'],
    "Stream":["[^'SCIENCE','COMMERCE']"]
},'',regex=True,inplace=True)

df1.Stream=df1["Stream"].replace(r'[A-Z]+SCIENCE',"SCIENCE",regex=True)
df1.Stream=df1["Stream"].replace(r'[A-Z]+COMMERCE',"COMMERCE",regex=True)

# %%
df1.head(60)
# Out:
#       Score                           Name    Stream
# 0     17                       Rifa ayesha   SCIENCE
# 1      21                          Preethi   SCIENCE
# 2     11                     Smaran shetty  COMMERCE
# 3    20                    Ashish v shetty   SCIENCE
# 4      24                            Vinit   SCIENCE
# 5    18                    Nisha u acharya  COMMERCE
# 6    24          Rahul Raghunath Shettigar  COMMERCE
# 7    20                   N RADHESH SHETTY   SCIENCE
# 8     19                     Mohammed adil  COMMERCE
# 9      25                           Sumith   SCIENCE
# 10     18                          Darshan  COMMERCE
# 11   24               Sayed Mohammed Afzal  COMMERCE
# 12    24                         Charan. K   SCIENCE
# 13     25                         Thrupthi  COMMERCE
# 14     20                           Damini  COMMERCE
# 15     22                        Vaishnavi   SCIENCE
# 16    20                   Poorna prajna.N  COMMERCE
# 17   23              B.g venugopal karanth  COMMERCE
# 18   22                     Thanvi S Sanil   SCIENCE
# 19     23                  Sharan.p.shetty  COMMERCE
# 20   24          Karthik Shashidhar Salian   SCIENCE
# 21     20                  Abhishek.s.shet   SCIENCE
# 22    17                         Neha Amin  COMMERCE
# 23   22         Meghna gopalkrishna salian  COMMERCE
# 24   21                    Veeraj n kotian  COMMERCE
# 25    21                    Rohith poojary  COMMERCE
# 26   21                      Pramod V Naik   SCIENCE
# 27   21                   Anshul A. Salian   SCIENCE
# 28    21                    Mohammed Irfan   SCIENCE
# 29    21                    Mohammed ciyaf   SCIENCE
# 30   23                   Vignesh s shetty  COMMERCE
# 31   23                    R Nayana kotian  COMMERCE
# 32    14                    Shivaprakash u  COMMERCE
# 33     22                   Abhay.G.Bhadri  COMMERCE
# 34    18                     Reshel Dsilva  COMMERCE
# 35     24                            AYUSH  COMMERCE
# 36   18                   P Sudharshan rao  COMMERCE
# 37  21                   Varsha  y Karkera  COMMERCE
# 38    24                        Varshith G   SCIENCE
# 39     20                          Karunya  COMMERCE
# 40   24                  Tanushri V Shetty  COMMERCE
# 41    23                        Poorvi Rao  COMMERCE
# 42     24              Deekshith.P.Poojary   SCIENCE
# 43   18               Prajwal. R. Devadiga   SCIENCE
# 44    23                         Manish PM   SCIENCE
# 45    19                        Syed yusuf   SCIENCE
# 46   22            shashidhar vishwakarma    SCIENCE
# 47    23                        samrudhi s  COMMERCE
# 48     20                           Arathi  COMMERCE
# 49   18              ROSHAN DENZIEL AMANNA   SCIENCE
# 50    24                    Sanjana Gunaga   SCIENCE
# 51    16                        Rahul bhat   SCIENCE
# 52   24                     ARYAN M CHOWTA   SCIENCE
# 53   22                    Ashith H kotian  COMMERCE
# 54    16                     Shraddha yeri   SCIENCE
# 55    21                    Mahammed Sinan   SCIENCE
# 56   23                  Manish. Y poojary  COMMERCE
# 57    22                    Krishna moolya  COMMERCE
# 58    20                      Vinayak bhat  COMMERCE
# 59     18                          shreyas   SCIENCE

# %%
df1.Name=df1.Name.str.lower()

# %%
df1.Score=df1.Score.apply(pd.to_numeric)

# %%
df1.Score.dtype
# Out:
# dtype('int64')

# %%
df1.head(10)
# Out:
#    Score                          Name    Stream
# 0     17                   rifa ayesha   SCIENCE
# 1     21                       preethi   SCIENCE
# 2     11                 smaran shetty  COMMERCE
# 3     20               ashish v shetty   SCIENCE
# 4     24                         vinit   SCIENCE
# 5     18               nisha u acharya  COMMERCE
# 6     24     rahul raghunath shettigar  COMMERCE
# 7     20              n radhesh shetty   SCIENCE
# 8     19                 mohammed adil  COMMERCE
# 9     25                        sumith   SCIENCE

# %%
df1.loc[df1.Score==25]
# Out:
#     Score                 Name    Stream
# 9      25               sumith   SCIENCE
# 13     25             thrupthi  COMMERCE
# 67     25     thrisha.u.shetty   SCIENCE

# %%
df1.loc[df1.Stream=='SCIENCE','Name']
# Out:
# 0                       rifa ayesha
# 1                           preethi
# 3                   ashish v shetty
# 4                             vinit
# 7                  n radhesh shetty
# 9                            sumith
# 12                        charan. k
# 15                        vaishnavi
# 18                   thanvi s sanil
# 20        karthik shashidhar salian
# 21                  abhishek.s.shet
# 26                    pramod v naik
# 27                 anshul a. salian
# 28                   mohammed irfan
# 29                   mohammed ciyaf
# 38                       varshith g
# 42              deekshith.p.poojary
# 43             prajwal. r. devadiga
# 44                        manish pm
# 45                       syed yusuf
# 46          shashidhar vishwakarma
# 49            roshan denziel amanna
# 50                   sanjana gunaga
# 51                       rahul bhat
# 52                   aryan m chowta
# 54                    shraddha yeri
# 55                   mahammed sinan
# 59                          shreyas
# 60                     sameeya banu
# 63                          lavanya
# 66                        sujal.a.m
# 67                 thrisha.u.shetty
# 69                darshan p suvarna
# 70                 varun s devadiga
# 72                  shravan bangera
# 73              prasheel.r.devadiga
# 75                     suhan ammann
# 77                    pramod shenoy
# 80                           deepak
# 82               raghavendra.s.naik
# 83                          vignesh
# 84                           amruth
# 86                  ruchitha prabhu
# 87                         krithika
# 90                deeksha s poojary
# 91                    ananya shetty
# 96                   guru madhava h
# 97                amritha.k.poojary
# 98                    akshay r bhat
# 104               gowrika g kuckian
# 110                             ...
# Name: Name, dtype: object
